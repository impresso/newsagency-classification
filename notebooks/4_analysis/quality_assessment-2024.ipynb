# %% [markdown]
# # Quality Assessment

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly
#   Downloading plotly-5.23.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /home/eboros/.conda/envs/myenv/lib/python3.11/site-packages (from plotly) (24.1)
# Downloading plotly-5.23.0-py3-none-any.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 85.8 MB/s eta 0:00:00:00:0100:01
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.23.0 tenacity-9.0.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
import plotly.graph_objects as go
from collections import Counter

pd.options.mode.chained_assignment = None  # default='warn'

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly
#   Downloading plotly-5.23.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /home/eboros/.conda/envs/myenv/lib/python3.11/site-packages (from plotly) (24.1)
# Downloading plotly-5.23.0-py3-none-any.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 28.3 MB/s eta 0:00:0000:0100:01
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.23.0 tenacity-9.0.0

# %% [markdown]
# ## Import data

# %%
input_path = "./../../data/inference/"
output_path = "./../../data/inference/"

input_path = 'data'
output_path = 'data'

decades = list(range(1840, 2000, 10))

# %%
# mentions_fr = pd.read_pickle(input_path + "mentions_fr.pkl")
# mentions_de = pd.read_pickle(input_path + 'mentions_de.pkl')
# all_mentions = pd.concat([mentions_fr, mentions_de])

mentions = pd.read_pickle(input_path + '/mentions.pkl')

# assert(len(all_mentions) == 4482890)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 # mentions_fr = pd.read_pickle(input_path + "mentions_fr.pkl")
#       2 # mentions_de = pd.read_pickle(input_path + 'mentions_de.pkl')
#       3 # all_mentions = pd.concat([mentions_fr, mentions_de])
# ----> 5 mentions = pd.read_pickle(input_path + '/mentions.pkl')
#       7 # assert(len(all_mentions) == 4482890)
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     199     with warnings.catch_warnings(record=True):
#     200         # We want to silence any warnings about, e.g. moved modules.
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#     207     return pc.load(handles.handle, encoding=None)
#
# File ~/.conda/envs/myenv/lib/python3.11/site-packages/numpy/core/numeric.py:1851, in _frombuffer(buf, dtype, shape, order)
#    1845     return function(*args, **kwargs)
#    1848 _fromfunction_with_like = array_function_dispatch()(fromfunction)
# -> 1851 def _frombuffer(buf, dtype, shape, order):
#    1852     return frombuffer(buf, dtype=dtype).reshape(shape, order=order)
#    1855 @set_module('numpy')
#    1856 def isscalar(element):
#
# KeyboardInterrupt:

# %%
len(mentions)

# %%
len(mentions)
# Out:
# 5390328

# %% [markdown]
# ## Sample and Check articles per decade

# %%
def sample_per_dec(df, decade, n=5):
    df_dec = df[df['decade']==decade]

    if len(df_dec) < n:
        return df_dec
    else:
        return df_dec.sample(n, random_state=2023)

# %%
df_sampled = pd.DataFrame()
for decade in decades:
    # df_sampled = pd.concat([df_sampled, 
    #                         sample_per_dec(mentions_fr, decade),
    #                         sample_per_dec(mentions_de, decade)])
    df_sampled = pd.concat([df_sampled, 
                            sample_per_dec(mentions, decade)])

# %%
print(f"For the manual quality check, {len(df_sampled)} articles were sampled.")
df_sampled.head(2)
# Out:
# For the manual quality check, 80 articles were sampled.
#                           entity surface  qid  lSentenceOffset  \
# 1586362   pers.ind.articleauthor      F.                  6814
# 5511173  org.ent.pressagency.unk      .-  NIL             2077
#
#          rSentenceOffset sentence_idx  lArticleOffset  rArticleOffset  \
# 1586362             6816                         6814            6816
# 5511173             2079                         2077            2079
#
#                                                         id  \
# 1586362  6814:6816:pers.ind.articleauthor:dbmdz_bert_ba...
# 5511173  2077:2079:org.ent.pressagency.unk:dbmdz_bert_b...
#
#                          article newspaper        date  year  decade  \
# 1586362   EXP-1840-03-12-a-i0001       EXP  1840-03-12  1840    1840
# 5511173  jdpl-1845-12-06-a-i0027      jdpl  1845-12-06  1845    1840
#
#                 agency language  country
# 1586362  articleauthor  unknown  unknown
# 5511173            unk  unknown  unknown

# %%
#prepare data for manual check & export
df_to_check = df_sampled.copy()
df_to_check['impresso_link'] = "impresso-project.ch/app/article/" + df_to_check['article']

df_check = df_to_check[['agency', 'surface', 'impresso_link', 'id']] #'sentence_idx:', 

#export
df_to_check.to_csv(output_path + "samples_quality_assessment.csv")

df_to_check.head()
# Out:
#                           entity     surface  qid  lSentenceOffset  \
# 4925465  org.ent.pressagency.unk     . A. Z.  NIL             4727
# 5104126   pers.ind.articleauthor  M. GARNIER  NIL             7092
# 4925563  org.ent.pressagency.unk         . Z  NIL             2204
# 4924905  org.ent.pressagency.unk          Z.  NIL             7707
# 5297580  org.ent.pressagency.unk       V.-H.  NIL             7974
#
#          rSentenceOffset sentence_idx  lArticleOffset  rArticleOffset  \
# 4925465             4734                         4727            4734
# 5104126             7102                         7092            7102
# 4925563             2207                         2204            2207
# 4924905             7709                         7707            7709
# 5297580             7979                         7974            7979
#
#                                                         id  \
# 4925465  4727:4734:org.ent.pressagency.unk:dbmdz_bert_b...
# 5104126  7092:7102:pers.ind.articleauthor:dbmdz_bert_ba...
# 4925563  2204:2207:org.ent.pressagency.unk:dbmdz_bert_b...
# 4924905  7707:7709:org.ent.pressagency.unk:dbmdz_bert_b...
# 5297580  7974:7979:org.ent.pressagency.unk:dbmdz_bert_b...
#
#                             article newspaper        date  year  decade  \
# 4925465      NZZ-1841-07-07-a-i0002       NZZ  1841-07-07  1841    1840
# 5104126     jdpl-1848-01-22-a-i0014      jdpl  1848-01-22  1848    1840
# 4925563      NZZ-1841-08-30-a-i0002       NZZ  1841-08-30  1841    1840
# 4924905      NZZ-1841-03-08-a-i0002       NZZ  1841-03-08  1841    1840
# 5297580  luxwort-1849-10-28-a-i0007   luxwort  1849-10-28  1849    1840
#
#                 agency language  country  \
# 4925465            unk  unknown  unknown
# 5104126  articleauthor  unknown  unknown
# 4925563            unk  unknown  unknown
# 4924905            unk  unknown  unknown
# 5297580            unk  unknown  unknown
#
#                                              impresso_link
# 4925465  impresso-project.ch/app/article/NZZ-1841-07-07...
# 5104126  impresso-project.ch/app/article/jdpl-1848-01-2...
# 4925563  impresso-project.ch/app/article/NZZ-1841-08-30...
# 4924905  impresso-project.ch/app/article/NZZ-1841-03-08...
# 5297580  impresso-project.ch/app/article/luxwort-1849-1...

# %% [markdown]
# ### Reimport checked data

# %%
df_checked = pd.read_csv(input_path + '/samples_quality_assessment_filled.csv')
print(f"all columns in df: {df_checked.columns}")
df_checked = df_checked.drop(columns=['agency', 'surface', 'impresso_link', 'dev.impresso_link', 'context']).merge(
    df_sampled, on='id', how='inner'
) #'sentence_idx:', 
assert len(df_checked) == len(df_sampled)

df_checked.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_checked = pd.read_csv(input_path + '/samples_quality_assessment_filled.csv')
#       2 print(f"all columns in df: {df_checked.columns}")
#       3 df_checked = df_checked.drop(columns=['agency', 'surface', 'impresso_link', 'dev.impresso_link', 'context']).merge(
#       4     df_sampled, on='id', how='inner'
#       5 ) #'sentence_idx:',
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/samples_quality_assessment_filled.csv'

# %% [markdown]
# ### Stats: Quality of the classification

# %%
print(f"correctly classified: {round(len(df_checked[df_checked['is_correct']]) / len(df_checked) * 100)} %")
df_checked_19th = df_checked[df_checked['decade'] < 1900]
df_checked_20th = df_checked[df_checked['decade'] >= 1900]
print(f"-> 19th century: {round(len(df_checked_19th[df_checked_19th['is_correct']]) / len(df_checked_19th) * 100)} %")
print(f"-> 20th century: {round(len(df_checked_20th[df_checked_20th['is_correct']]) / len(df_checked_20th) * 100)} %")
# Out:
# correctly classified: 62 %
# -> 19th century: 27 %
# -> 20th century: 83 %

# %%
df_checked_dec = df_checked[['decade', 'language', 'is_correct', 'has_brackets', 'has_hyphen', 'has_dot']].groupby(by=['decade', 'language']).mean().reset_index()
df_checked_dec[['is_correct', 'has_brackets', 'has_hyphen', 'has_dot']] = df_checked_dec[['is_correct', 'has_brackets', 'has_hyphen', 'has_dot']] * 100
df_checked_dec.head()
# Out:
#    decade language  is_correct  has_brackets  has_hyphen  has_dot
# 0    1840       de         0.0           0.0        20.0     20.0
# 1    1840       fr        20.0          80.0        20.0    100.0
# 2    1850       de         0.0           0.0         0.0     80.0
# 3    1850       fr         0.0         100.0        20.0    100.0
# 4    1860       de         0.0          40.0         0.0     80.0

# %%
#over time
fig, ax = plt.subplots(1, figsize=(10,5))

ax.plot(decades, df_checked_dec.loc[df_checked_dec['language'] == 'fr', 'is_correct'], label='fr')
ax.plot(decades, df_checked_dec.loc[df_checked_dec['language'] == 'de', 'is_correct'], label='de')
ax.legend()
ax.set_ylabel('% correctly classified')
plt.show()

# %% [markdown]
# ### Check out wrongly classified tokens

# %%
wrongly_classified = df_checked[~df_checked['is_correct']]
wrongly_classified.head()
# Out:
#                                                   id  is_correct  \
# 0  LNF-1847-09-03-a-i0003:50:1:5:4427:4431:newsag...       False
# 1  LNF-1847-09-28-a-i0001:21:1:3:2243:2245:newsag...       False
# 2  LCG-1849-09-22-a-i0003:38:1:9:5797:5805:newsag...       False
# 4  LSR-1847-05-08-a-i0009:11:-1:4:897:902:newsag:...       False
# 5  WHD-1845-02-07-a-i0006:53:0:7:2441:2448:newsag...       False
#
#      correct_tag  has_brackets  has_hyphen  has_dot  \
# 0              O          True       False     True
# 1              O          True       False     True
# 2              O          True       False     True
# 4  articleauthor          True       False     True
# 5  articleauthor         False       False    False
#
#                       entity   surface       qid  lSentenceOffset  ...  \
# 0  org.ent.pressagency.Havas      Nouv  Q2826560                1  ...
# 1  org.ent.pressagency.Havas        Id  Q2826560                1  ...
# 2  org.ent.pressagency.Havas  Hclvétie  Q2826560                1  ...
# 4    org.ent.pressagency.unk     .- E.       NIL               -1  ...
# 5  org.ent.pressagency.Havas   Desaaas  Q2826560                0  ...
#
#    lArticleOffset  rArticleOffset                 article  newspaper  \
# 0            4427            4431  LNF-1847-09-03-a-i0003        LNF
# 1            2243            2245  LNF-1847-09-28-a-i0001        LNF
# 2            5797            5805  LCG-1849-09-22-a-i0003        LCG
# 4             897             902  LSR-1847-05-08-a-i0009        LSR
# 5            2441            2448  WHD-1845-02-07-a-i0006        WHD
#
#          date  year decade  agency  language country
# 0  1847-09-03  1847   1840   Havas        fr      CH
# 1  1847-09-28  1847   1840   Havas        fr      CH
# 2  1849-09-22  1849   1840   Havas        fr      CH
# 4  1847-05-08  1847   1840     unk        fr      CH
# 5  1845-02-07  1845   1840   Havas        de      CH
#
# [5 rows x 22 columns]

# %%
print(f"Percent of wrongly classified mentions which...\n{wrongly_classified[['has_brackets', 'has_hyphen', 'has_dot']].mean() * 100}")

print(f"Percent of wrongly classified mentions which has neither of them: {100 - round(wrongly_classified[['has_brackets', 'has_hyphen', 'has_dot']].any(axis=1).mean() * 100)} %")
# Out:
# Percent of wrongly classified mentions which...
# has_brackets    52.459016
# has_hyphen       6.557377
# has_dot         63.934426
# dtype: float64
# Percent of wrongly classified mentions which has neither of them: 23 %

# %%
wrongly_classified['agency'].unique()
# Out:
# array(['Havas', 'unk', 'ag', 'SPK-SMP', 'Reuters', 'Wolff', 'ATS-SDA',
#        'DPA', 'AFP', 'UP-UPI'], dtype=object)

# %% [markdown]
# #### Sankey Diagram

# %%
correct_tokens = list(wrongly_classified['correct_tag'].unique())
wrong_tokens =  [token + "_" for token in wrongly_classified['agency'].unique()]
all_tokens = correct_tokens + wrong_tokens
tokens_dict = dict(zip(all_tokens, list(range(len(all_tokens)))))
print(tokens_dict)

freq_wrong_class = Counter(zip(wrongly_classified['correct_tag'], wrongly_classified['agency']))
print(freq_wrong_class)
source = [tokens_dict[keys[0]] for keys in freq_wrong_class.keys()]
target = [tokens_dict[keys[1]+"_"] for keys in freq_wrong_class.keys()]
value = list(freq_wrong_class.values())
# Out:
# {'O': 0, 'articleauthor': 1, 'Havas': 2, 'unk': 3, 'Reuters': 4, 'Wolff': 5, 'Havas_': 6, 'unk_': 7, 'ag_': 8, 'SPK-SMP_': 9, 'Reuters_': 10, 'Wolff_': 11, 'ATS-SDA_': 12, 'DPA_': 13, 'AFP_': 14, 'UP-UPI_': 15}
# Counter({('O', 'unk'): 13, ('O', 'Havas'): 9, ('O', 'SPK-SMP'): 6, ('O', 'ATS-SDA'): 6, ('articleauthor', 'unk'): 4, ('O', 'ag'): 4, ('articleauthor', 'Havas'): 3, ('O', 'Reuters'): 3, ('Wolff', 'Havas'): 3, ('O', 'DPA'): 2, ('O', 'AFP'): 2, ('O', 'Wolff'): 1, ('Havas', 'unk'): 1, ('unk', 'Havas'): 1, ('Reuters', 'unk'): 1, ('articleauthor', 'ATS-SDA'): 1, ('O', 'UP-UPI'): 1})

# %%
fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 20,
      thickness = 30,
      line = dict(color = "black", width = 0.6),
      label = list(tokens_dict.keys()), #["A1", "A2", "B1", "B2", "C1", "C2"],
      color = "blue"
    ),
    link = dict(
      source = source, # indices correspond to labels, eg A1, A2, A1, B1, ...
      target = target,
      value = value
  ))])

labels = "Correct Label" + 35 * "\t" + "Wrong Label"

fig.update_layout(title_text=labels, font_size=20, autosize=False,
    width=800,
    height=600,)
fig.show()

# %%
#check case of Havas per time
havas = df_checked[df_checked['agency'] == "Havas"]
havas_grouped = havas[['decade', 'is_correct', 'agency']].groupby('decade').agg({'is_correct': 'mean', 'agency': 'count'})
havas_grouped['is_correct'] = havas_grouped['is_correct'] * 100

fig, ax = plt.subplots()
ax1 = ax.twinx()

lns1 = ax.plot(havas_grouped.index, havas_grouped['is_correct'], label='correctly classified')
lns2 = ax1.bar(havas_grouped.index, havas_grouped['agency'], color='grey', alpha=0.1, label='#checked classifications')
ax.set_ylabel("% correctly classified")
ax1.set_ylabel("#checked classifications")
ax.legend()
plt.show()

# %%
# check language for wrongly classified Wolff tokens
wrongly_classified[wrongly_classified['correct_tag'] == "Wolff"]
# Out:
#                                                    id  is_correct correct_tag  \
# 71  EXP-1916-04-14-a-i0115:3:0:5:320:325:newsag:be...       False       Wolff
# 74  JDG-1916-06-09-a-i0029:46:1:6:6067:6072:newsag...       False       Wolff
# 92  EXP-1930-07-28-a-i0098:0:42:47:42:47:newsag:be...       False       Wolff
#
#     has_brackets  has_hyphen  has_dot                     entity surface  \
# 71         False       False    False  org.ent.pressagency.Havas   Wolff
# 74          True       False     True  org.ent.pressagency.Havas   Wolff
# 92          True       False     True  org.ent.pressagency.Havas   Wolff
#
#          qid  lSentenceOffset  ...  lArticleOffset  rArticleOffset  \
# 71  Q2826560                0  ...             320             325
# 74  Q2826560                1  ...            6067            6072
# 92  Q2826560               42  ...              42              47
#
#                    article  newspaper        date  year decade  agency  \
# 71  EXP-1916-04-14-a-i0115        EXP  1916-04-14  1916   1910   Havas
# 74  JDG-1916-06-09-a-i0029        JDG  1916-06-09  1916   1910   Havas
# 92  EXP-1930-07-28-a-i0098        EXP  1930-07-28  1930   1930   Havas
#
#     language country
# 71        fr      CH
# 74        fr      CH
# 92        fr      CH
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Check use of "unk" token

# %%
df_unk = all_mentions[all_mentions['agency'] == "unk"]

# %%
print(f"#articles classified as 'unk': {len(df_unk)} ({round(len(df_unk)/len(all_mentions)*100)}% of all classified agency mentions)")
# Out:
# #articles classified as 'unk': 177922 (4% of all classified agency mentions)

# %%
df_unk['surface'].value_counts()[:50]
# Out:
# . P.             12656
# Fournier          9027
# Bureau            7708
# FN                7316
# D. N. B.          7163
# . T. S            3478
# Telunion          3332
# Korrespondenz     3053
# . N. B.           2981
# Cosmo             2927
# C. P.             2871
# az                2869
# Agence            2779
# Kp                1737
# KP                1660
# Belga             1659
# S.                1642
# . S.              1474
# SR                1434
# APRIL             1387
# Agency            1384
# havas             1338
# . T. S.           1259
# Amtlich           1198
# . T.              1173
# Uniteb            1120
# Agenzia           1054
# . B.               951
# GB                 920
# ry                 902
# S. Sp.             881
# SBolff             849
# Sp                 844
# TASS               812
# . P. S.            787
# B. C. V.           747
# S. P.              714
# CND                688
# sr                 687
# Spx                684
# ugu                648
# ADN                645
# P. T. S.           616
# KIPA               606
# C. P. S.           605
# AWP                591
# T. P.              591
# Interinf           553
# C. N. B.           517
# Taß                510
# Name: surface, dtype: int64

# %%
df_unk[df_unk['surface']=="FN"].head()
# Out:
#                        entity surface  qid  lSentenceOffset  rSentenceOffset  \
# 252   org.ent.pressagency.unk      FN  NIL                2                4
# 2718  org.ent.pressagency.unk      FN  NIL                2                4
# 2779  org.ent.pressagency.unk      FN  NIL                2                4
# 3164  org.ent.pressagency.unk      FN  NIL                2                4
# 3320  org.ent.pressagency.unk      FN  NIL                2                4
#
#       sentence_idx:  lArticleOffset  rArticleOffset  \
# 252               2             324             326
# 2718              1             125             127
# 2779             10            1065            1067
# 3164             31            5968            5970
# 3320             15            1060            1062
#
#                                                      id  \
# 252   FZG-1981-11-25-a-i0028:2:2:4:324:326:newsag:be...
# 2718  FZG-1992-06-19-a-i0169:1:2:4:125:127:newsag:be...
# 2779  FZG-1991-08-05-a-i0056:10:2:4:1065:1067:newsag...
# 3164  FZG-1986-04-21-a-i0094:31:2:4:5968:5970:newsag...
# 3320  FZG-1988-07-21-a-i0092:15:2:4:1060:1062:newsag...
#
#                      article newspaper        date  year  decade agency  \
# 252   FZG-1981-11-25-a-i0028       FZG  1981-11-25  1981    1980    unk
# 2718  FZG-1992-06-19-a-i0169       FZG  1992-06-19  1992    1990    unk
# 2779  FZG-1991-08-05-a-i0056       FZG  1991-08-05  1991    1990    unk
# 3164  FZG-1986-04-21-a-i0094       FZG  1986-04-21  1986    1980    unk
# 3320  FZG-1988-07-21-a-i0092       FZG  1988-07-21  1988    1980    unk
#
#      language country
# 252        de      CH
# 2718       de      CH
# 2779       de      CH
# 3164       de      CH
# 3320       de      CH

# %%
df_unk.loc[df_unk['surface']=="FN", 'newspaper'].unique()
# Out:
# array(['FZG'], dtype=object)

# %% [markdown]
# -> abbreviation for "Freiburger Nachrichten"

# %%
df_unk[df_unk['surface']==". P."].head(10)
# Out:
#                        entity surface  qid  lSentenceOffset  rSentenceOffset  \
# 1240  org.ent.pressagency.unk    . P.  NIL               65               69
# 2015  org.ent.pressagency.unk    . P.  NIL               70               74
# 2813  org.ent.pressagency.unk    . P.  NIL               -1                3
# 4503  org.ent.pressagency.unk    . P.  NIL                4                8
# 4737  org.ent.pressagency.unk    . P.  NIL                4                8
# 4822  org.ent.pressagency.unk    . P.  NIL              315              319
# 4873  org.ent.pressagency.unk    . P.  NIL                4                8
# 5297  org.ent.pressagency.unk    . P.  NIL               43               47
# 5298  org.ent.pressagency.unk    . P.  NIL               53               57
# 6032  org.ent.pressagency.unk    . P.  NIL               97              101
#
#       sentence_idx:  lArticleOffset  rArticleOffset  \
# 1240              0              65              69
# 2015              0              70              74
# 2813             44            8784            8788
# 4503             10             886             890
# 4737              7             393             397
# 4822              3            2929            2933
# 4873              6             572             576
# 5297              0              43              47
# 5298              4             395             399
# 6032              1             173             177
#
#                                                      id  \
# 1240  IMP-1960-05-18-a-i0043:0:65:69:65:69:newsag:be...
# 2015  JDG-1957-08-19-a-i0076:0:70:74:70:74:newsag:be...
# 2813  LLE-1974-11-21-a-i0150:44:-1:3:8784:8788:newsa...
# 4503  GDL-1942-04-21-a-i0054:10:4:8:886:890:newsag:b...
# 4737  JDG-1952-08-08-a-i0108:7:4:8:393:397:newsag:be...
# 4822  GDL-1952-09-12-a-i0083:3:315:319:2929:2933:new...
# 4873  JDG-1948-10-15-a-i0022:6:4:8:572:576:newsag:be...
# 5297  GDL-1950-09-11-a-i0090:0:43:47:43:47:newsag:be...
# 5298  GDL-1950-09-11-a-i0090:4:53:57:395:399:newsag:...
# 6032  EXP-1957-06-20-a-i0005:1:97:101:173:177:newsag...
#
#                      article newspaper        date  year  decade agency  \
# 1240  IMP-1960-05-18-a-i0043       IMP  1960-05-18  1960    1960    unk
# 2015  JDG-1957-08-19-a-i0076       JDG  1957-08-19  1957    1950    unk
# 2813  LLE-1974-11-21-a-i0150       LLE  1974-11-21  1974    1970    unk
# 4503  GDL-1942-04-21-a-i0054       GDL  1942-04-21  1942    1940    unk
# 4737  JDG-1952-08-08-a-i0108       JDG  1952-08-08  1952    1950    unk
# 4822  GDL-1952-09-12-a-i0083       GDL  1952-09-12  1952    1950    unk
# 4873  JDG-1948-10-15-a-i0022       JDG  1948-10-15  1948    1940    unk
# 5297  GDL-1950-09-11-a-i0090       GDL  1950-09-11  1950    1950    unk
# 5298  GDL-1950-09-11-a-i0090       GDL  1950-09-11  1950    1950    unk
# 6032  EXP-1957-06-20-a-i0005       EXP  1957-06-20  1957    1950    unk
#
#      language country
# 1240       fr      CH
# 2015       fr      CH
# 2813       fr      CH
# 4503       fr      CH
# 4737       fr      CH
# 4822       fr      CH
# 4873       fr      CH
# 5297       fr      CH
# 5298       fr      CH
# 6032       fr      CH

# %% [markdown]
# - IMP-1960-05-18-a-i0043: C.P. -> Correspondance Particulière
# - JDG-1957-08-19-a-i0076: D. P. A. -> DPA
# - LLE-1974-11-21-a-i0150:  ( J . P . ) -> articleauthor (?)
# - GDL-1942-04-21-a-i0054: (C. P.) -> Correspondance Particulière
# - JDG-1952-08-08-a-i0108: (C. P.) -> Correspondance Particulière
# - GDL-1952-09-12-a-i0083: (C. P.) -> Correspondance Particulière
# - JDG-1948-10-15-a-i0022: (S. P.) -> unk
# - GDL-1950-09-11-a-i0090: (C. P.) -> Correspondance Particulière
# - GDL-1950-09-11-a-i0090: (C. P.) -> Correspondance Particulière
# - EXP-1957-06-20-a-i0005: (D. P. A.) -> DPA

# %% [markdown]
# -> part of (C.P.), correspondance particulière (?) - often appears with local news

# %%
#Agence Fournier: 1874 - 1944
sns.countplot(df_unk[df_unk['surface'] == 'Fournier'], x='decade')
# Out:
# <Axes: xlabel='decade', ylabel='count'>

# %%
#DNB
sns.countplot(df_unk[df_unk['surface'] == '. N. B.'], x='decade')
# Out:
# <Axes: xlabel='decade', ylabel='count'>

# %%
sns.countplot(df_unk[df_unk['surface'] == '. T. S'], x='decade')
# Out:
# <Axes: xlabel='decade', ylabel='count'>

# %%
all_mentions = mentions

# %% [markdown]
# ## Check ratio of noisy mentions

# %%
print(f"#unique tokens (surface) classified as agency: {len(all_mentions['surface'].unique())}")
print(f"Most common ones:\n{all_mentions['surface'].value_counts()[:50]}")
# Out:
# #unique tokens (surface) classified as agency: 156730
# Most common ones:
# surface
# ag              699574
# Havas           617388
# AFP             523754
# Reuter          501150
# ats             392736
# ATS             248949
# ap              235896
# afp             138589
# United Press    136415
# a p             131929
# ag.             124301
# AP               87798
# UPI              87643
# ATP              70427
# Wolff            67264
# ABI              51571
# .-               50065
# DPA              45988
# Afp              44487
# A. F. P.         44087
# Exchange         43628
# DNB              40410
# Œuvre            34738
# Kipa             32613
# sda              29486
# DM               28417
# . B.             28320
# United Preß      27611
# L. S.            27385
# reuter           24937
# Ag.              23153
# UP               22226
# D.               20773
# s p              19766
# sp               19628
# Ats              19055
# de               18022
# Ap               17257
# A.               16736
# z. B.            16341
# C. P.            16120
# L.               15730
# S.               13809
# . S              13091
# D. N. B.         13055
# H.               12864
# . S.             12391
# F.               11964
# U. P.            11885
# Agence           11679
# Name: count, dtype: int64

# %%
print(f"#unique tokens (surface) classified as agency: {len(all_mentions['surface'].unique())}")
print(f"Most common ones:\n{all_mentions['surface'].value_counts()[:50]}")
# Out:
# #unique tokens (surface) classified as agency: 36496
# Most common ones:
# AFP             670833
# ATS             581200
# Reuter          379627
# ats             356665
# ag.             283871
# Havas           267151
# sda             196004
# afp             159931
# AP              155882
# ap              105499
# United Press     73433
# A. F. P.         64703
# UPI              58647
# Wolff            49105
# Afp              47740
# ag               44696
# ATP              44290
# Kipa             39263
# reuter           37811
# dpa              34564
# DPA              32148
# Exchange         29572
# DNB              28448
# spk              27295
# United Preß      25449
# Ats              24239
# Ap               19434
# ag)              15306
# . P.             13157
# Preß             12908
# United           12489
# UP               11039
# FN                9389
# Agence            9173
# Fournier          9089
# U. P.             8905
# A. T. S.          8465
# Bureau            7708
# Ag                7607
# si                7470
# upi               7412
# D. N. B.          7163
# SDA               7017
# reuters           6366
# Haoas             6028
# AfS               5951
# Agentur           5715
# ddp               5482
# sp                5214
# Stefani           4833
# Name: surface, dtype: int64

# %%
#plot most common surfaces
most_common_surface = all_mentions['surface'].value_counts()[:40]

fig, ax = plt.subplots(1, figsize=(12,4))

ax.bar(most_common_surface.index, most_common_surface.values)
plt.xticks(rotation=90)
plt.show()

# %%
#plot most common surfaces
most_common_surface = all_mentions['surface'].value_counts()[:40]

fig, ax = plt.subplots(1, figsize=(12,4))

ax.bar(most_common_surface.index, most_common_surface.values)
plt.xticks(rotation=90)
plt.show()

# %%
all_mentions[all_mentions['surface']=="ATP"].sample(5, random_state=2023)
# Out:
#                           entity surface     qid  lSentenceOffset  \
# 1560561  org.ent.pressagency.AFP     ATP                    16172
# 4999601  org.ent.pressagency.AFP     ATP                      305
# 3513947  org.ent.pressagency.AFP     ATP  Q40464             2835
# 1445321  org.ent.pressagency.AFP     ATP                      188
# 4882314  org.ent.pressagency.AFP     ATP                     3826
#
#          rSentenceOffset sentence_idx  lArticleOffset  rArticleOffset  \
# 1560561            16175                        16172           16175
# 4999601              308                          305             308
# 3513947             2838                         2835            2838
# 1445321              191                          188             191
# 4882314             3829                         3826            3829
#
#                                                         id  \
# 1560561  16172:16175:org.ent.pressagency.AFP:dbmdz_bert...
# 4999601  305:308:org.ent.pressagency.AFP:dbmdz_bert_bas...
# 3513947  2835:2838:org.ent.pressagency.AFP:dbmdz_bert_b...
# 1445321  188:191:org.ent.pressagency.AFP:dbmdz_bert_bas...
# 4882314  3826:3829:org.ent.pressagency.AFP:dbmdz_bert_b...
#
#                         article newspaper        date  year  decade agency  \
# 1560561  EXP-2015-07-20-a-i0212       EXP  2015-07-20  2015    2010    AFP
# 4999601  LLE-1993-10-23-a-i0341       LLE  1993-10-23  1993    1990    AFP
# 3513947  IMP-2005-06-25-a-i0189       IMP  2005-06-25  2005    2000    AFP
# 1445321  EXP-1994-06-14-a-i0242       EXP  1994-06-14  1994    1990    AFP
# 4882314  LLE-2008-04-11-a-i0160       LLE  2008-04-11  2008    2000    AFP
#
#         language  country
# 1560561  unknown  unknown
# 4999601  unknown  unknown
# 3513947  unknown  unknown
# 1445321  unknown  unknown
# 4882314  unknown  unknown

# %%
all_mentions[all_mentions['surface']=="ATP"].sample(5, random_state=2023)
# Out:
#                           entity surface     qid  lSentenceOffset  \
# 2296437  org.ent.pressagency.AFP     ATP  Q40464               64
# 3346332  org.ent.pressagency.AFP     ATP  Q40464               82
# 2499846  org.ent.pressagency.AFP     ATP  Q40464               57
# 3812651  org.ent.pressagency.AFP     ATP  Q40464                2
# 2240865  org.ent.pressagency.AFP     ATP  Q40464               19
#
#          rSentenceOffset  sentence_idx:  lArticleOffset  rArticleOffset  \
# 2296437               67              0              64              67
# 3346332               85              2             225             228
# 2499846               60              1             172             175
# 3812651                5              5             281             284
# 2240865               22              1             203             206
#
#                                                         id  \
# 2296437  EXP-2010-11-11-a-i0144:0:64:67:64:67:newsag:be...
# 3346332  LLE-2010-12-24-a-i0127:2:82:85:225:228:newsag:...
# 2499846  EXP-2016-04-20-a-i0204:1:57:60:172:175:newsag:...
# 3812651  IMP-1948-09-25-a-i0153:5:2:5:281:284:newsag:be...
# 2240865  EXP-2007-09-12-a-i0205:1:19:22:203:206:newsag:...
#
#                         article newspaper        date  year  decade agency  \
# 2296437  EXP-2010-11-11-a-i0144       EXP  2010-11-11  2010    2010    AFP
# 3346332  LLE-2010-12-24-a-i0127       LLE  2010-12-24  2010    2010    AFP
# 2499846  EXP-2016-04-20-a-i0204       EXP  2016-04-20  2016    2010    AFP
# 3812651  IMP-1948-09-25-a-i0153       IMP  1948-09-25  1948    1940    AFP
# 2240865  EXP-2007-09-12-a-i0205       EXP  2007-09-12  2007    2000    AFP
#
#         language country
# 2296437       fr      CH
# 3346332       fr      CH
# 2499846       fr      CH
# 3812651       fr      CH
# 2240865       fr      CH

# %%
all_mentions.loc[all_mentions['surface']=="ATP", 'agency'].value_counts()
# Out:
# agency
# AFP       70426
# UP-UPI        1
# Name: count, dtype: int64

# %%
all_mentions.loc[all_mentions['surface']=="ATP", 'agency'].value_counts()
# Out:
# AFP        44268
# ATS-SDA       21
# unk            1
# Name: agency, dtype: int64

# %% [markdown]
# - EXP-2010-11-11-a-i0144: Association of Tennis Professionals (ATP)
# - LLE-2010-12-24-a-i0127: Association of Tennis Professionals (ATP)
# - EXP-2016-04-20-a-i0204: Association of Tennis Professionals (ATP)
# - IMP-1948-09-25-a-i0153: AFP
# - EXP-2007-09-12-a-i0205: Association of Tennis Professionals (ATP)

# %%
sns.countplot(all_mentions[all_mentions['surface']=="ATP"], x='decade')
# Out:
# <Axes: xlabel='decade', ylabel='count'>

# %%
sns.countplot(all_mentions[all_mentions['surface']=="ATP"], x='decade')
# Out:
# <Axes: xlabel='decade', ylabel='count'>

# %% [markdown]
# -> Association of Tennis Professionals (ATP) was founded in 1972

# %%
sns.countplot(all_mentions[all_mentions['surface']=="si"], x='decade')
plt.xticks(rotation=90)
plt.show()

# %%
all_mentions.loc[all_mentions['surface']=="si", 'agency'].value_counts()
# Out:
# ATS-SDA    7434
# Havas        21
# AP           12
# AFP           1
# Wolff         1
# unk           1
# Name: agency, dtype: int64

# %%
all_mentions.loc[all_mentions['surface']=="si"].head()
# Out:
#                              entity surface       qid  lSentenceOffset  \
# 46652     org.ent.pressagency.Havas      si  Q2826560              284
# 100650       org.ent.pressagency.AP      si    Q40469               38
# 542694  org.ent.pressagency.ATS-SDA      si   Q430109              189
# 575380       org.ent.pressagency.AP      si    Q40469              288
# 692312    org.ent.pressagency.Havas      si  Q2826560                4
#
#         rSentenceOffset  sentence_idx:  lArticleOffset  rArticleOffset  \
# 46652               286             14            2746            2748
# 100650               40             19            2711            2713
# 542694              191             12            2875            2877
# 575380              290             28            3167            3169
# 692312                6            166            7292            7294
#
#                                                        id  \
# 46652   IMP-1994-07-16-a-i0066:14:284:286:2746:2748:ne...
# 100650  IMP-1992-06-19-a-i0127:19:38:40:2711:2713:news...
# 542694  EXP-1993-08-14-a-i0161:12:189:191:2875:2877:ne...
# 575380  IMP-1992-02-19-a-i0085:28:288:290:3167:3169:ne...
# 692312  IMP-1994-05-09-a-i0077:166:4:6:7292:7294:newsa...
#
#                        article newspaper        date  year  decade   agency  \
# 46652   IMP-1994-07-16-a-i0066       IMP  1994-07-16  1994    1990    Havas
# 100650  IMP-1992-06-19-a-i0127       IMP  1992-06-19  1992    1990       AP
# 542694  EXP-1993-08-14-a-i0161       EXP  1993-08-14  1993    1990  ATS-SDA
# 575380  IMP-1992-02-19-a-i0085       IMP  1992-02-19  1992    1990       AP
# 692312  IMP-1994-05-09-a-i0077       IMP  1994-05-09  1994    1990    Havas
#
#        language country
# 46652        fr      CH
# 100650       fr      CH
# 542694       fr      CH
# 575380       fr      CH
# 692312       fr      CH

# %% [markdown]
# - IMP-1994-07-16-a-i0066: (si)
# - IMP-1992-06-19-a-i0127: (ap/si)
# - EXP-1993-08-14-a-i0161: / si-ats
# - IMP-1992-02-19-a-i0085: (ap / si)
# - IMP-1994-05-09-a-i0077: (si)
#
# -> Schweizer Sportnachrichtenagentur Sportinformation (SI) (founded 1922)

# %% [markdown]
# ### Rough ratio of noisy mentions

# %%
all_mentions['surface'].value_counts()[:50].index
# Out:
# Index(['ag', 'Havas', 'AFP', 'Reuter', 'ats', 'ATS', 'ap', 'afp',
#        'United Press', 'a p', 'ag.', 'AP', 'UPI', 'ATP', 'Wolff', 'ABI', '.-',
#        'DPA', 'Afp', 'A. F. P.', 'Exchange', 'DNB', 'Œuvre', 'Kipa', 'sda',
#        'DM', '. B.', 'United Preß', 'L. S.', 'reuter', 'Ag.', 'UP', 'D.',
#        's p', 'sp', 'Ats', 'de', 'Ap', 'A.', 'z. B.', 'C. P.', 'L.', 'S.',
#        '. S', 'D. N. B.', 'H.', '. S.', 'F.', 'U. P.', 'Agence'],
#       dtype='object', name='surface')

# %%
#check noisy mentions manually
all_mentions['surface'].value_counts()[:50].index
# Out:
# Index(['AFP', 'ATS', 'Reuter', 'ats', 'ag.', 'Havas', 'sda', 'afp', 'AP', 'ap',
#        'United Press', 'A. F. P.', 'UPI', 'Wolff', 'Afp', 'ag', 'ATP', 'Kipa',
#        'reuter', 'dpa', 'DPA', 'Exchange', 'DNB', 'spk', 'United Preß', 'Ats',
#        'Ap', 'ag)', '. P.', 'Preß', 'United', 'UP', 'FN', 'Agence', 'Fournier',
#        'U. P.', 'A. T. S.', 'Bureau', 'Ag', 'si', 'upi', 'D. N. B.', 'SDA',
#        'reuters', 'Haoas', 'AfS', 'Agentur', 'ddp', 'sp', 'Stefani'],
#       dtype='object')

# %%
not_noisy_ag_surface = ['AFP', 'ATS', 'Reuter', 'ats', 'ag.', 'Havas', 'sda', 'afp', 'AP', 'ap',
       'United Press', 'A. F. P.', 'UPI', 'Wolff', 'Afp', 'ag', 'Kipa',
       'reuter', 'dpa', 'DPA', 'Exchange', 'DNB', 'spk', 'United Preß', 'Ats',
       'Ap', 'ag)', 'Preß', 'United', 'UP', 'Fournier', 'Agence',
       'U. P.', 'A. T. S.', 'Bureau', 'Ag', 'upi', 'D. N. B.', 'SDA',
       'reuters', 'Agentur', 'ddp', 
 'Stefani',
 'Tass',
 'Europapreß',
 'télégraphique',
 'up',
 'Agence télégraphique suisse',
 'Telunion',
 'Korrespondenz',
 'C. P.',
 'Belga',
 'télégraphique suisse',
 'Press',
 'havas',
 'APA',
 'A. F. P',
 'Ansa',
 'Ag.',
 'Taß',
 'Agency',
 'Ofi',
 'REUTER',
 'A. T. S',
 'Interinf',
 'Agenzia',
 'Extel',
 'D. P. A.',
 'TASS',
 'Nouvelle',
 'Associated',
 'Telepress',
 'apa',
 'Keystone',
 'ANSA',
 'KIPA',
 'P. T. S.',
 'Dpa',
 'Agence télégraphique',
 ]

# %%
print(f"Most frequent noisy/unknown mentions:\n{[surface for surface in all_mentions['surface'].value_counts()[:200].index if surface not in not_noisy_ag_surface]},\nFrequency of last checked item: {all_mentions['surface'].value_counts()[200]}")
# Out:
# Most frequent noisy/unknown mentions:
# ['ATP', '. P.', 'FN', 'si', 'Haoas', 'AfS', 'sp', 'Ilavas', 'Hauas', 'ag(', 'Sp', 'az', 'suivre', '. T. S', 'DNV', 'llavas', 'at', 'ag,', 'apx', '. N. B.', 'Cosmo', 'DP', '. P', 'agr.', 'GB', 'fdp', 'resp', 'Reuler', 'svp', 'Resp', 'af', 'Rey', 'sdi', 'Kp', 'ju', 'Beuter', 'KP', 'dds', 'APS', 'S.', 'AT', '. S.', 'Bavas', 'pk', 'APRIL', 'AFS', 'pw', 'Europapreh', 'SR', '. T.', 'A. S.', 'APP', 'A. T.', '. T. S.', 'Saas', 'Hanas', 'bp', 'Hava', 'Amtlich', 'DRB', 'Uniteb', 'TS', 'sr', 'ASL', 'ADN', 'AF', '. B.', 'A TS', 'Rex', 'ry', 'Renier', 'U. P', 'spg', 'span', 'S. Sp.', 'ATE', 'sw', 'SBolff', 'APEI', 'At', 'APIC', 'United Preh', '. P. S.', 'Haras', 'B. C. V.', 'APG', 'pp', 'Spx', 'DR', 'CND', 'Uniled Press', 'S. P.', 'tp', 'APF', 'API', 'stv', 'DK', 'KPI', 'DNN', 'ATÇ', 'AWP', 'ugu', 'IDNB', 'A. B.', 'SNB', 'Europapretz', 'A.', 'C. P. S.', 'AJt', 'Reu', 'T. P.', 'A. R.', 'P.', 'A. T', 'alp', 'APD', 'Libertas', 'DIE', 'CPS', 'Af', 'Bp'],
# Frequency of last checked item: 536

# %%
df_noisy_surface = all_mentions[~all_mentions['surface'].isin(not_noisy_ag_surface)]

print(f"Rough ratio of noisy mentions: {round(len(df_noisy_surface) / len(all_mentions) *100, 2)}%")
print(f"Rough ratio of noisy mentions, unk excluded: {round(len(df_noisy_surface[df_noisy_surface['agency'] != 'unk']) / len(all_mentions) *100, 2)}%")
print(f"Rough ratio of noisy mentions, unk excluded, FR:\
    {round(len(df_noisy_surface[(df_noisy_surface['language'] == 'fr') & (df_noisy_surface['agency'] != 'unk')]) / len(mentions_fr) *100, 2)}%")
print(f"Rough ratio of noisy mentions, unk excluded, DE:\
    {round(len(df_noisy_surface[(df_noisy_surface['language'] == 'de') & (df_noisy_surface['agency'] != 'unk')]) / len(mentions_de) *100, 2)}%")
# Out:
# Rough ratio of noisy mentions: 10.63%
# Rough ratio of noisy mentions, unk excluded: 7.69%
# Rough ratio of noisy mentions, unk excluded, FR:    6.4%
# Rough ratio of noisy mentions, unk excluded, DE:    9.96%

# %% [markdown]
# -> more or less the same as in annotated set, German a bit more

# %% [markdown]
# ## The token ag.

# %%
all_mentions[all_mentions['agency'] == 'ag'].sample(10, random_state=1)
# Out:
#                          entity surface qid  lSentenceOffset  rSentenceOffset  \
# 1286075  org.ent.pressagency.ag      ag                 1118             1120
# 2789150  org.ent.pressagency.ag   agéfi                 1113             1118
# 2490252  org.ent.pressagency.ag      ag               228990           228992
# 17942    org.ent.pressagency.ag      ag                 5969             5971
# 374153   org.ent.pressagency.ag      ag                 6792             6794
# 234723   org.ent.pressagency.ag      ag                 6117             6119
# 151897   org.ent.pressagency.ag      ag                 3506             3508
# 1241109  org.ent.pressagency.ag      ag                 4088             4090
# 398010   org.ent.pressagency.ag      ng                 3923             3925
# 769678   org.ent.pressagency.ag      ag                 6999             7001
#
#         sentence_idx  lArticleOffset  rArticleOffset  \
# 1286075                         1118            1120
# 2789150                         1113            1118
# 2490252                       228990          228992
# 17942                           5969            5971
# 374153                          6792            6794
# 234723                          6117            6119
# 151897                          3506            3508
# 1241109                         4088            4090
# 398010                          3923            3925
# 769678                          6999            7001
#
#                                                         id  \
# 1286075  1118:1120:org.ent.pressagency.ag:dbmdz_bert_ba...
# 2789150  1113:1118:org.ent.pressagency.ag:dbmdz_bert_ba...
# 2490252  228990:228992:org.ent.pressagency.ag:dbmdz_ber...
# 17942    5969:5971:org.ent.pressagency.ag:dbmdz_bert_ba...
# 374153   6792:6794:org.ent.pressagency.ag:dbmdz_bert_ba...
# 234723   6117:6119:org.ent.pressagency.ag:dbmdz_bert_ba...
# 151897   3506:3508:org.ent.pressagency.ag:dbmdz_bert_ba...
# 1241109  4088:4090:org.ent.pressagency.ag:dbmdz_bert_ba...
# 398010   3923:3925:org.ent.pressagency.ag:dbmdz_bert_ba...
# 769678   6999:7001:org.ent.pressagency.ag:dbmdz_bert_ba...
#
#                              article newspaper        date  year  decade  \
# 1286075       DTT-1960-11-09-a-i0005       DTT  1960-11-09  1960    1960
# 2789150       GDL-1959-01-16-a-i0031       GDL  1959-01-16  1959    1950
# 2490252  FedGazDe-1888-11-03-a-i0001  FedGazDe  1888-11-03  1888    1880
# 17942         DTT-1966-09-05-a-i0138       DTT  1966-09-05  1966    1960
# 374153        DTT-1959-10-30-a-i0029       DTT  1959-10-30  1959    1950
# 234723        DTT-1956-03-29-a-i0025       DTT  1956-03-29  1956    1950
# 151897        DTT-1965-04-30-a-i0119       DTT  1965-04-30  1965    1960
# 1241109       DTT-1958-04-02-a-i0043       DTT  1958-04-02  1958    1950
# 398010        DTT-1963-05-07-a-i0069       DTT  1963-05-07  1963    1960
# 769678        DTT-1963-09-05-a-i0037       DTT  1963-09-05  1963    1960
#
#         agency language  country
# 1286075     ag  unknown  unknown
# 2789150     ag  unknown  unknown
# 2490252     ag  unknown  unknown
# 17942       ag  unknown  unknown
# 374153      ag  unknown  unknown
# 234723      ag  unknown  unknown
# 151897      ag  unknown  unknown
# 1241109     ag  unknown  unknown
# 398010      ag  unknown  unknown
# 769678      ag  unknown  unknown

# %%
all_mentions[all_mentions['agency'] == 'ag'].sample(10, random_state=1)
# Out:
#                          entity surface  qid  lSentenceOffset  \
# 3223402  org.ent.pressagency.ag     ag.  NIL               -1
# 2262562  org.ent.pressagency.ag     ag-  NIL               26
# 4320085  org.ent.pressagency.ag     ag,  NIL               -1
# 4567015  org.ent.pressagency.ag     ag.  NIL               -1
# 728842   org.ent.pressagency.ag      ag  NIL               36
# 3032765  org.ent.pressagency.ag     ag.  NIL               -1
# 3950711  org.ent.pressagency.ag     ag.  NIL               -1
# 1626610  org.ent.pressagency.ag     ag.  NIL               -1
# 1855841  org.ent.pressagency.ag      ag  NIL               32
# 2069783  org.ent.pressagency.ag     ag.  NIL               -1
#
#          rSentenceOffset  sentence_idx:  lArticleOffset  rArticleOffset  \
# 3223402                2              8            4761            4764
# 2262562               29             31            2467            2470
# 4320085                2            191           21848           21851
# 4567015                2              1              63              66
# 728842                38              0              36              38
# 3032765                2             54            5741            5744
# 3950711                2             80            8037            8040
# 1626610                2             36            8288            8291
# 1855841               34             92           13955           13957
# 2069783                2            134           11496           11499
#
#                                                         id  \
# 3223402  FZG-1951-09-29-a-i0040:8:-1:2:4761:4764:newsag...
# 2262562  FZG-1990-03-07-a-i0159:31:26:29:2467:2470:news...
# 4320085  NZZ-1944-01-27-d-i0001:191:-1:2:21848:21851:ne...
# 4567015  FZG-1965-04-09-a-i0102:1:-1:2:63:66:newsag:ber...
# 728842   DTT-1959-09-20-a-i0057:0:36:38:36:38:newsag:be...
# 3032765  FZG-1965-12-20-a-i0017:54:-1:2:5741:5744:newsa...
# 3950711  FZG-1958-10-20-a-i0051:80:-1:2:8037:8040:newsa...
# 1626610  FZG-1925-03-06-a-i0004:36:-1:2:8288:8291:newsa...
# 1855841  DTT-1965-12-19-a-i0070:92:32:34:13955:13957:ne...
# 2069783  FZG-1940-12-19-a-i0028:134:-1:2:11496:11499:ne...
#
#                         article newspaper        date  year  decade agency  \
# 3223402  FZG-1951-09-29-a-i0040       FZG  1951-09-29  1951    1950     ag
# 2262562  FZG-1990-03-07-a-i0159       FZG  1990-03-07  1990    1990     ag
# 4320085  NZZ-1944-01-27-d-i0001       NZZ  1944-01-27  1944    1940     ag
# 4567015  FZG-1965-04-09-a-i0102       FZG  1965-04-09  1965    1960     ag
# 728842   DTT-1959-09-20-a-i0057       DTT  1959-09-20  1959    1950     ag
# 3032765  FZG-1965-12-20-a-i0017       FZG  1965-12-20  1965    1960     ag
# 3950711  FZG-1958-10-20-a-i0051       FZG  1958-10-20  1958    1950     ag
# 1626610  FZG-1925-03-06-a-i0004       FZG  1925-03-06  1925    1920     ag
# 1855841  DTT-1965-12-19-a-i0070       DTT  1965-12-19  1965    1960     ag
# 2069783  FZG-1940-12-19-a-i0028       FZG  1940-12-19  1940    1940     ag
#
#         language country
# 3223402       de      CH
# 2262562       de      CH
# 4320085       de      CH
# 4567015       de      CH
# 728842        de      CH
# 3032765       de      CH
# 3950711       de      CH
# 1626610       de      CH
# 1855841       de      CH
# 2069783       de      CH

# %%
all_mentions[all_mentions['agency'] == 'ag'].sample(10, random_state=1)['article']
# Out:
# 1286075         DTT-1960-11-09-a-i0005
# 2789150         GDL-1959-01-16-a-i0031
# 2490252    FedGazDe-1888-11-03-a-i0001
# 17942           DTT-1966-09-05-a-i0138
# 374153          DTT-1959-10-30-a-i0029
# 234723          DTT-1956-03-29-a-i0025
# 151897          DTT-1965-04-30-a-i0119
# 1241109         DTT-1958-04-02-a-i0043
# 398010          DTT-1963-05-07-a-i0069
# 769678          DTT-1963-09-05-a-i0037
# Name: article, dtype: object

# %%
for mention in all_mentions[all_mentions['agency'] == 'ag']['article'].unique():
    if 'DTT' in mention:
        print(mention)

# %%
all_mentions[all_mentions['agency'] == 'ag'].sample(10, random_state=1)['article']
# Out:
# 3223402    FZG-1951-09-29-a-i0040
# 2262562    FZG-1990-03-07-a-i0159
# 4320085    NZZ-1944-01-27-d-i0001
# 4567015    FZG-1965-04-09-a-i0102
# 728842     DTT-1959-09-20-a-i0057
# 3032765    FZG-1965-12-20-a-i0017
# 3950711    FZG-1958-10-20-a-i0051
# 1626610    FZG-1925-03-06-a-i0004
# 1855841    DTT-1965-12-19-a-i0070
# 2069783    FZG-1940-12-19-a-i0028
# Name: article, dtype: object

# %% [markdown]
# - FZG-1951-09-29-a-i0040: ag - Switzerland
#     - Bern , 29 . Sept . **ag .** Der bernische Regierungsrat nahm Kenntnis von einem Schreiben der eidg . Bundeskanzlei
# - FZG-1990-03-07-a-i0159: FP
#     - Von Beginn weg spielte es **ag-** Bern : Tosio ; Leuenberger , Rauch ; Beutler gressiv auf den Mann
# - NZZ-1944-01-27-d-i0001: FP
#     - klar durchhörbare Toug^slalt gewiuueu ließ , '.!>;! **ag ,** ^ril .! Bru » i « seine » späleren -inionie » sich ,', u ei » e ,» selb »
# - FZG-1965-04-09-a-i0102: ag + DPA
#     - Berlin , 8 . April , **ag .** ( DPA ) Ueberraschend wurde zum erstenmal die Fernverkehrsstraße
# - DTT-1959-09-20-a-i0057: ag - Switzerland
#     - Sitten , **( ag )** In einem Stollen im Val de Bagnes , wo zwei Arbeiter und ein Vorarbeiter beschäftigt waren , ist ein Felsblock
# - FZG-1965-12-20-a-i0017: ag - Switzerland
#     - Messe für die über Weihnachten heimkehrenden Gastarbeiter , **ag .** Im Kollegium San . Antonio in Locarno hielt ein Priester der bischöflichen Mission
# - FZG-1958-10-20-a-i0051: ag - Switzerland
#     - Brüssel , 19 . Okt . **ag .** Die Weltausstellung Brüssel 1958 hat am Sonntag ihre Pforten geschlossen . Es ist offensichtlich noch zu früh , um eine —• - auch nur annähernde — Bilanz der Resultate der schweizerischen Beteiligung an der Ausstellung zu ziehen .
# - FZG-1925-03-06-a-i0004: ag + Havas
#     - Lonbon , 5 . März . **ag .** •( Havas . ) In einer Rede , bie Viscount Grey am Mittwoch
# - DTT-1965-12-19-a-i0070: ag - Switzerland
#     - Lausanne , **( ag )** Wie in Lausanne bekanntgegeben wurde , ist die Schweizerische Landesausstellung 1964
# - FZG-1940-12-19-a-i0028: ag - foreign news
#     - Washington , 19 . Dez . **ag .** Staatssekretär Eordell Hüll teilte in der Pressekonferenz mit , daß der amerikanische Geschäftsträger

# %%
all_mentions.loc[all_mentions['agency'] == 'ag', 'newspaper'].value_counts()
# Out:
# newspaper
# DTT                770538
# GDL                 61964
# lepetitparisien     21423
# FedGazDe            14061
# FedGazFr             8564
# luxwort              6651
# lematin              4029
# obermosel            2675
# EXP                  2655
# JDG                  2430
# LLE                  2374
# oerennes             1379
# luxembourg1935       1237
# IMP                  1156
# esta                  847
# oeuvre                807
# arbeitgeber           655
# legaulois             494
# tageblatt             489
# jdpl                  433
# handelsztg            408
# excelsior             306
# NZZ                   257
# luxland               175
# GAV                   121
# volkfreu1869          114
# lafronde              112
# LLS                   111
# NV2                   100
# FZG                    88
# NV1                    87
# lepji                  77
# waechtersauer          73
# EZR                    71
# luxzeit1844            45
# lunion                 34
# luxzeit1858            27
# JV                     14
# MB                     13
# JVE                    11
# marieclaire            10
# AV                      9
# BNN                     9
# JH                      9
# DFS                     9
# CDV                     6
# waeschfra               5
# onsjongen               5
# ME                      4
# GAZ                     4
# Cancoire                3
# DLE                     3
# schmiede                2
# NS                      2
# CharivariCH             1
# landwortbild            1
# TouSuIl                 1
# FAN                     1
# NV                      1
# DVF                     1
# Name: count, dtype: int64

# %%
all_mentions.loc[all_mentions['agency'] == 'ag', 'newspaper'].value_counts()
# Out:
# FZG               264400
# DTT                68807
# NZZ                17825
# luxwort              957
# obermosel            405
# SMZ                  360
# VHT                  304
# OIZ                  219
# buergerbeamten       117
# SGZ                  116
# NTS                  115
# tageblatt             87
# LLE                   63
# luxland               56
# BNN                   48
# NZG                   45
# dunioun               45
# EZR                   39
# LAB                   38
# waechtersauer         21
# deletz1893            17
# FCT                   11
# DFS                   11
# WHD                   11
# DLE                    8
# armeteufel             6
# diekwochen             6
# volkfreu1869           5
# courriergdl            4
# DVF                    3
# HRV                    3
# luxzeit1844            2
# indeplux               2
# waeschfra              2
# MGS                    2
# landwortbild           1
# luxzeit1858            1
# demitock               1
# Name: newspaper, dtype: int64

# %%
print(f"% of total ag. mentions in newspaper")
all_mentions.loc[all_mentions['agency'] == 'ag', 'newspaper'].value_counts()/len(all_mentions.loc[all_mentions['agency'] == 'ag'])
# Out:
# % of total ag. mentions in newspaper
# FZG               0.746549
# DTT               0.194281
# NZZ               0.050330
# luxwort           0.002702
# obermosel         0.001144
# SMZ               0.001016
# VHT               0.000858
# OIZ               0.000618
# buergerbeamten    0.000330
# SGZ               0.000328
# NTS               0.000325
# tageblatt         0.000246
# LLE               0.000178
# luxland           0.000158
# BNN               0.000136
# NZG               0.000127
# dunioun           0.000127
# EZR               0.000110
# LAB               0.000107
# waechtersauer     0.000059
# deletz1893        0.000048
# FCT               0.000031
# DFS               0.000031
# WHD               0.000031
# DLE               0.000023
# armeteufel        0.000017
# diekwochen        0.000017
# volkfreu1869      0.000014
# courriergdl       0.000011
# DVF               0.000008
# HRV               0.000008
# luxzeit1844       0.000006
# indeplux          0.000006
# waeschfra         0.000006
# MGS               0.000006
# landwortbild      0.000003
# luxzeit1858       0.000003
# demitock          0.000003
# Name: newspaper, dtype: float64

# %%
matplotlib.rcParams.update({'font.size': 14})
FZG = all_mentions[(all_mentions['newspaper'] == 'FZG') & (all_mentions['decade'] >= 1900)]
FZG_grouped = FZG[['agency', 'year', 'article']].groupby(['agency', 'year']).count().reset_index().pivot(columns='agency', index='year')
FZG_grouped.columns = FZG_grouped.columns.droplevel()

FZG_grouped.plot.line(figsize=(16,8), cmap='tab20', title="FZG: Cited Agencies")
# Out:
# <Axes: title={'center': 'FZG: Cited Agencies'}, xlabel='year'>

# %%
matplotlib.rcParams.update({'font.size': 14})
FZG = all_mentions[(all_mentions['newspaper'] == 'FZG') & (all_mentions['decade'] >= 1900)]
FZG_grouped = FZG[['agency', 'year', 'article']].groupby(['agency', 'year']).count().reset_index().pivot(columns='agency', index='year')
FZG_grouped.columns = FZG_grouped.columns.droplevel()

FZG_grouped.plot.line(figsize=(16,8), cmap='tab20', title="FZG: Cited Agencies")
# Out:
# <Axes: title={'center': 'FZG: Cited Agencies'}, xlabel='year'>

# %%
DTT = all_mentions[(all_mentions['newspaper'] == 'DTT') & (all_mentions['decade'] >= 1900)]
DTT_grouped = DTT[['agency', 'year', 'article']].groupby(['agency', 'year']).count().reset_index().pivot(columns='agency', index='year')
DTT_grouped.columns = DTT_grouped.columns.droplevel()
DTT_grouped.plot.line(figsize=(16,8), cmap='tab20', title="DTT: Cited Agencies")
# Out:
# <Axes: title={'center': 'DTT: Cited Agencies'}, xlabel='year'>

# %%
DTT = all_mentions[(all_mentions['newspaper'] == 'DTT') & (all_mentions['decade'] >= 1900)]
DTT_grouped = DTT[['agency', 'year', 'article']].groupby(['agency', 'year']).count().reset_index().pivot(columns='agency', index='year')
DTT_grouped.columns = DTT_grouped.columns.droplevel()
DTT_grouped.plot.line(figsize=(16,8), cmap='tab20', title="DTT: Cited Agencies")
# Out:
# <Axes: title={'center': 'DTT: Cited Agencies'}, xlabel='year'>

# %%
NZZ = all_mentions[(all_mentions['newspaper'] == 'NZZ') & (all_mentions['decade'] >=  1900)]
NZZ_grouped = NZZ[['agency', 'year', 'article']].groupby(['agency', 'year']).count().reset_index().pivot(columns='agency', index='year')
NZZ_grouped.columns = NZZ_grouped.columns.droplevel()
NZZ_grouped.plot.line(figsize=(16,8), cmap='tab20', title="NZZ: Cited Agencies")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2 NZZ_grouped = NZZ[['agency', 'year', 'article']].groupby(['agency', 'year']).count().reset_index().pivot(columns='agency', index='year')
#       3 NZZ_grouped.columns = NZZ_grouped.columns.droplevel()
# ----> 4 NZZ_grouped.plot.line(figsize=(16,8), cmap='tab20', title="NZZ: Cited Agencies")
#
# File ~/.local/lib/python3.11/site-packages/pandas/plotting/_core.py:1100, in PlotAccessor.line(self, x, y, **kwargs)
#    1034 @Appender(
#    1035     """
#    1036     See Also
#    (...)
#    1092     self, x: Hashable | None = None, y: Hashable | None = None, **kwargs
#    1093 ) -> PlotAccessor:
#    1094     """
#    1095     Plot Series or DataFrame as lines.
#    1096
#    1097     This function is useful to plot lines using DataFrame's values
#    1098     as coordinates.
#    1099     """
# -> 1100     return self(kind="line", x=x, y=y, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/.local/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# --> 499     self._compute_plot_data()
#     500     fig = self.fig
#     501     self._make_plot(fig)
#
# File ~/.local/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:698, in MPLPlot._compute_plot_data(self)
#     696 # no non-numeric frames or series allowed
#     697 if is_empty:
# --> 698     raise TypeError("no numeric data to plot")
#     700 self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
NZZ = all_mentions[(all_mentions['newspaper'] == 'NZZ') & (all_mentions['decade'] >=  1900)]
NZZ_grouped = NZZ[['agency', 'year', 'article']].groupby(['agency', 'year']).count().reset_index().pivot(columns='agency', index='year')
NZZ_grouped.columns = NZZ_grouped.columns.droplevel()
NZZ_grouped.plot.line(figsize=(16,8), cmap='tab20', title="NZZ: Cited Agencies")
# Out:
# <Axes: title={'center': 'NZZ: Cited Agencies'}, xlabel='year'>

# %%
matplotlib.rcParams.update({'font.size': 10})

# %% [markdown]
# ## Havas after 1940

# %%
ax = all_mentions.loc[all_mentions['agency'] == 'Havas', ['year', 'article']].groupby('year').count().plot.line()
ax.axvline(1940, color='red')
ax.set_title('Havas over time')
# Out:
# Text(0.5, 1.0, 'Havas over time')

# %%
ax = all_mentions.loc[all_mentions['agency'] == 'Havas', ['year', 'article']].groupby('year').count().plot.line()
ax.axvline(1940, color='red')
ax.set_title('Havas over time')
# Out:
# Text(0.5, 1.0, 'Havas over time')

# %%
Havas1941 = all_mentions[(all_mentions['agency'] == 'Havas') & (all_mentions['year'].isin(list(range(1941, 1950))))]
Havas1941.head()
# Out:
#                          entity surface       qid  lSentenceOffset  \
# 717   org.ent.pressagency.Havas  Renier  Q2826560                3
# 769   org.ent.pressagency.Havas      ag  Q2826560                1
# 1715  org.ent.pressagency.Havas  Reuter  Q2826560               69
# 2223  org.ent.pressagency.Havas  Reuter  Q2826560               63
# 2374  org.ent.pressagency.Havas      Ag  Q2826560               97
#
#       rSentenceOffset  sentence_idx:  lArticleOffset  rArticleOffset  \
# 717                 9              1              62              68
# 769                 3              2              62              64
# 1715               75              9            1499            1505
# 2223               69              0              63              69
# 2374               99              0              97              99
#
#                                                      id  \
# 717   JDG-1944-01-12-a-i0081:1:3:9:62:68:newsag:bert_fr
# 769   GDL-1942-04-29-a-i0019:2:1:3:62:64:newsag:bert_fr
# 1715  EXP-1948-04-05-a-i0003:9:69:75:1499:1505:newsa...
# 2223  EXP-1944-02-07-a-i0088:0:63:69:63:69:newsag:be...
# 2374  GDL-1942-02-13-a-i0021:0:97:99:97:99:newsag:be...
#
#                      article newspaper        date  year  decade agency  \
# 717   JDG-1944-01-12-a-i0081       JDG  1944-01-12  1944    1940  Havas
# 769   GDL-1942-04-29-a-i0019       GDL  1942-04-29  1942    1940  Havas
# 1715  EXP-1948-04-05-a-i0003       EXP  1948-04-05  1948    1940  Havas
# 2223  EXP-1944-02-07-a-i0088       EXP  1944-02-07  1944    1940  Havas
# 2374  GDL-1942-02-13-a-i0021       GDL  1942-02-13  1942    1940  Havas
#
#      language country
# 717        fr      CH
# 769        fr      CH
# 1715       fr      CH
# 2223       fr      CH
# 2374       fr      CH

# %%
Havas1941['surface'].value_counts()[:20]
# Out:
# Havas        6112
# Ag           4934
# ag           4570
# Stefani      1565
# Agentur      1019
# Ofi           913
# Reuter        545
# Renier        496
# Telepress     461
# Agence        458
# Saas          336
# suivre        246
# Sp            207
# Etas          129
# Hauas         110
# DNB           107
# Haoas          96
# Eeuter         93
# Presa          91
# Reuler         86
# Name: surface, dtype: int64

# %%
Havas1941.loc[Havas1941['surface'].str.startswith('Ha'), 'surface'].value_counts()[:20]
# Out:
# Havas        6112
# Hauas         110
# Haoas          96
# Hava           44
# HavaZ          19
# Havns          14
# Havae          13
# Ha             10
# Hanas          10
# Havard          7
# Hayas           7
# Haig            6
# Havoz           6
# Hava8           5
# Havaa           5
# Havos           4
# Havai           4
# Hava3           4
# Havekotte       3
# HavasOfi        3
# Name: surface, dtype: int64

# %%
Havas1941[Havas1941['surface'] == 'Havas'].sample(10, random_state=1)
# Out:
#                             entity surface       qid  lSentenceOffset  \
# 4649     org.ent.pressagency.Havas   Havas  Q2826560                2
# 3007249  org.ent.pressagency.Havas   Havas  Q2826560                2
# 3393035  org.ent.pressagency.Havas   Havas  Q2826560                2
# 3571530  org.ent.pressagency.Havas   Havas  Q2826560                2
# 2356627  org.ent.pressagency.Havas   Havas  Q2826560                3
# 460242   org.ent.pressagency.Havas   Havas  Q2826560              112
# 2794232  org.ent.pressagency.Havas   Havas  Q2826560                1
# 4508699  org.ent.pressagency.Havas   Havas  Q2826560                2
# 4377980  org.ent.pressagency.Havas   Havas  Q2826560                2
# 119710   org.ent.pressagency.Havas   Havas  Q2826560              102
#
#          rSentenceOffset  sentence_idx:  lArticleOffset  rArticleOffset  \
# 4649                   7             48            6332            6337
# 3007249                7             40            2645            2650
# 3393035                7              8             980             985
# 3571530                7             36            4935            4940
# 2356627                8              1              52              57
# 460242               117              4             941             946
# 2794232                6             12             913             918
# 4508699                7             43            7376            7381
# 4377980                7              1              83              88
# 119710               107              0             102             107
#
#                                                         id  \
# 4649     DTT-1942-08-12-a-i0036:48:2:7:6332:6337:newsag...
# 3007249  FZG-1941-11-15-a-i0097:40:2:7:2645:2650:newsag...
# 3393035  LLE-1942-05-29-a-i0024:8:2:7:980:985:newsag:be...
# 3571530  IMP-1942-06-30-a-i0101:36:2:7:4935:4940:newsag...
# 2356627  JDG-1942-09-05-a-i0020:1:3:8:52:57:newsag:bert_fr
# 460242   EXP-1941-04-02-a-i0047:4:112:117:941:946:newsa...
# 2794232  LSE-1942-05-20-a-i0033:12:1:6:913:918:newsag:b...
# 4508699  DTT-1942-03-09-a-i0025:43:2:7:7376:7381:newsag...
# 4377980  LLE-1942-06-10-a-i0007:1:2:7:83:88:newsag:bert_fr
# 119710   EXP-1941-09-13-a-i0006:0:102:107:102:107:newsa...
#
#                         article newspaper        date  year  decade agency  \
# 4649     DTT-1942-08-12-a-i0036       DTT  1942-08-12  1942    1940  Havas
# 3007249  FZG-1941-11-15-a-i0097       FZG  1941-11-15  1941    1940  Havas
# 3393035  LLE-1942-05-29-a-i0024       LLE  1942-05-29  1942    1940  Havas
# 3571530  IMP-1942-06-30-a-i0101       IMP  1942-06-30  1942    1940  Havas
# 2356627  JDG-1942-09-05-a-i0020       JDG  1942-09-05  1942    1940  Havas
# 460242   EXP-1941-04-02-a-i0047       EXP  1941-04-02  1941    1940  Havas
# 2794232  LSE-1942-05-20-a-i0033       LSE  1942-05-20  1942    1940  Havas
# 4508699  DTT-1942-03-09-a-i0025       DTT  1942-03-09  1942    1940  Havas
# 4377980  LLE-1942-06-10-a-i0007       LLE  1942-06-10  1942    1940  Havas
# 119710   EXP-1941-09-13-a-i0006       EXP  1941-09-13  1941    1940  Havas
#
#         language country
# 4649          de      CH
# 3007249       de      CH
# 3393035       fr      CH
# 3571530       fr      CH
# 2356627       fr      CH
# 460242        fr      CH
# 2794232       fr      CH
# 4508699       de      CH
# 4377980       fr      CH
# 119710        fr      CH

# %%
Havas1941[Havas1941['surface'] == 'Havas'].sample(10, random_state=1)['article']
# Out:
# 4649       DTT-1942-08-12-a-i0036
# 3007249    FZG-1941-11-15-a-i0097
# 3393035    LLE-1942-05-29-a-i0024
# 3571530    IMP-1942-06-30-a-i0101
# 2356627    JDG-1942-09-05-a-i0020
# 460242     EXP-1941-04-02-a-i0047
# 2794232    LSE-1942-05-20-a-i0033
# 4508699    DTT-1942-03-09-a-i0025
# 4377980    LLE-1942-06-10-a-i0007
# 119710     EXP-1941-09-13-a-i0006
# Name: article, dtype: object

# %% [markdown]
# - DTT-1942-08-12-a-i0036:
#     - Paris , 11 . Aug . ( Havas-OFI . ) Die deutschen Polizeibehörden veröffentlichen folgende Bekanntmachung :
# - FZG-1941-11-15-a-i0097:
#     -  Vichy , 15 . Nov . ag . ( Havas » Ofi . ) Von zuftändiger Stelle wird gemeldet , daß
# - LLE-1942-05-29-a-i0024:
#     -  ( Havas . ) — Le minislère de l air brésilien publie le communiqué suivant :
# - IMP-1942-06-30-a-i0101: TOURS, 30. — Havas-Ofi — On a arrêté à Saint-Pierre-des-Corps
# - JDG-1942-09-05-a-i0020: Stockholm, 5. — (Havas-Ofi.) La tentative flç
# - EXP-1941-04-02-a-i0047: BELGBADE, 2 (Havas). — La question des modalités de la
# - LSE-1942-05-20-a-i0033: Paris, 19 mai. (Havas-Ofi.
# - DTT-1942-03-09-a-i0025: Washington , 8 . März . ( Havas-OFI . ) Das
# - LLE-1942-06-10-a-i0007: Washington , 10 juin . ( Havas . ) — L amiral Leahy a dit , au cours
#     - cited by EXP-1942-06-11-a-i0010 as Havas-O.F.I.
# - EXP-1941-09-13-a-i0006: ANKARA, 12 (Havas-O. F. L). — Un tremblement de terre
#
#
# ### -> Havas-OFI

# %%
all_mentions['newspaper'].unique()
# Out:
# array(['ACI', 'AV', 'BDC', 'BLB', 'BNN', 'CL', 'Cancoire', 'Castigat',
#        'Charivari', 'CharivariCH', 'Croquis', 'DFS', 'DLE', 'DTT', 'DVF',
#        'EDA', 'EM', 'EXP', 'EZR', 'FAM', 'FAN', 'FCT', 'FZG', 'FedGazDe',
#        'FedGazFr', 'GAV', 'GAVi', 'GAZ', 'GDL', 'Grelot', 'Griffe',
#        'Guepe1851', 'HRV', 'IMP', 'JDF', 'JDG', 'JDV', 'JH', 'JV', 'JVE',
#        'JY2', 'LAB', 'LBP', 'LCE', 'LCG', 'LCR', 'LCS', 'LES', 'LLE',
#        'LLS', 'LNF', 'LSE', 'LSR', 'LTF', 'LVE', 'MB', 'ME', 'MESSAGER',
#        'MGS', 'Moniteur', 'NS', 'NTS', 'NV1', 'NV2', 'NZG', 'NZZ', 'OBS',
#        'OIZ', 'PDL', 'RLA', 'SDT', 'SGZ', 'SMZ', 'TouSuIl', 'VHT', 'VVS',
#        'VVS1', 'WHD', 'ZBT', 'actionfem', 'arbeitgeber', 'armeteufel',
#        'avenirgdl', 'buergerbeamten', 'courriergdl', 'deletz1893',
#        'demitock', 'diekwochen', 'dunioun', 'esta', 'excelsior',
#        'gazgrdlux', 'handelsztg', 'indeplux', 'jdpl', 'lafronde',
#        'landwortbild', 'legaulois', 'lematin', 'lepetitparisien', 'lepji',
#        'lunion', 'luxembourg1935', 'luxland', 'luxwort', 'luxzeit1844',
#        'luxzeit1858', 'marieclaire', 'obermosel', 'oerennes', 'oeuvre',
#        'onsjongen', 'schmiede', 'tageblatt', 'volkfreu1869',
#        'waechtersauer', 'waeschfra'], dtype=object)

# %%
newspaper = 'JDG'

DTT = all_mentions[all_mentions['newspaper'] == newspaper]
print(len(DTT))
DTT_grouped = DTT[['agency', 'year', 'article']].groupby(['agency', 'year']).count().reset_index().pivot(columns='agency', index='year')
DTT_grouped.columns = DTT_grouped.columns.droplevel()
DTT_grouped.plot.line(figsize=(16,8), cmap='tab20', title=f"{newspaper}: Cited Agencies")
# Out:
# 659394
# <Axes: title={'center': 'JDG: Cited Agencies'}, xlabel='year'>
